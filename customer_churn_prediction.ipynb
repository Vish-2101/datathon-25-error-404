# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
df = pd.read_csv("model training\Customer_Data.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\RAINA\AppData\Local\Temp\ipykernel_29080\3688396677.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df = pd.read_csv("model training\Customer_Data.csv")
#   Customer_ID  Gender  Age Married        State  Number_of_Referrals  \
# 0   19877-DEL    Male   35      No        Delhi                    7
# 1   58353-MAH  Female   45     Yes  Maharashtra                   14
# 2   25063-WES    Male   51      No  West Bengal                    4
# 3   59787-KAR    Male   79      No    Karnataka                    3
# 4   28544-TAM  Female   80      No   Tamil Nadu                    3
#
#    Tenure_in_Months Value_Deal Phone_Service Multiple_Lines  ...  \
# 0                27        NaN           Yes             No  ...
# 1                13        NaN           Yes            Yes  ...
# 2                35     Deal 5           Yes             No  ...
# 3                21     Deal 4           Yes             No  ...
# 4                 8        NaN           Yes             No  ...
#
#     Payment_Method Monthly_Charge Total_Charges Total_Refunds  \
# 0      Credit Card           65.6        593.30          0.00
# 1      Credit Card           -4.0        542.40         38.33
# 2  Bank Withdrawal           73.9        280.85          0.00
# 3  Bank Withdrawal           98.0       1237.85          0.00
# 4      Credit Card           83.9        267.40          0.00
#
#   Total_Extra_Data_Charges Total_Long_Distance_Charges Total_Revenue  \
# 0                        0                      381.51        974.81
# 1                       10                       96.21        610.28
# 2                        0                      134.60        415.45
# 3                        0                      361.66       1599.51
# 4                        0                       22.14        289.54
#
#   Customer_Status   Churn_Category                   Churn_Reason
# 0          Stayed              NaN                            NaN
# 1          Stayed              NaN                            NaN
# 2         Churned       Competitor  Competitor had better devices
# 3         Churned  Dissatisfaction        Product dissatisfaction
# 4         Churned  Dissatisfaction            Network reliability
#
# [5 rows x 32 columns]

# %%
dropped_columns = ['Customer_ID', 'Churn_Category', 'Churn_Reason']
df = df.drop(dropped_columns, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       6418 non-null   object
#  1   Age                          6418 non-null   int64
#  2   Married                      6418 non-null   object
#  3   State                        6418 non-null   object
#  4   Number_of_Referrals          6418 non-null   int64
#  5   Tenure_in_Months             6418 non-null   int64
#  6   Value_Deal                   2870 non-null   object
#  7   Phone_Service                6418 non-null   object
#  8   Multiple_Lines               5796 non-null   object
#  9   Internet_Service             6418 non-null   object
#  10  Internet_Type                5028 non-null   object
#  11  Online_Security              5028 non-null   object
#  12  Online_Backup                5028 non-null   object
#  13  Device_Protection_Plan       5028 non-null   object
#  14  Premium_Support              5028 non-null   object
#  15  Streaming_TV                 5028 non-null   object
#  16  Streaming_Movies             5028 non-null   object
#  17  Streaming_Music              5028 non-null   object
#  18  Unlimited_Data               5028 non-null   object
#  19  Contract                     6418 non-null   object
#  20  Paperless_Billing            6418 non-null   object
#  21  Payment_Method               6418 non-null   object
#  22  Monthly_Charge               6418 non-null   float64
#  23  Total_Charges                6418 non-null   float64
#  24  Total_Refunds                6418 non-null   float64
#  25  Total_Extra_Data_Charges     6418 non-null   int64
#  26  Total_Long_Distance_Charges  6418 non-null   float64
#  27  Total_Revenue                6418 non-null   float64
#  28  Customer_Status              6418 non-null   object
# dtypes: float64(5), int64(4), object(20)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (6418, 29)

# %%
encoded_columns = ['Gender', 'Married', 'State', 'Value_Deal', 'Phone_Service', 'Multiple_Lines', 'Internet_Service', 'Internet_Type', 'Online_Security', 'Online_Backup', 'Device_Protection_Plan', 'Premium_Support', 'Streaming_TV', 'Streaming_Movies', 'Streaming_Music', 'Contract', 'Paperless_Billing', 'Payment_Method']
label_encoders = {}

# %%
for column in encoded_columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Gender  Age  Married  State  Number_of_Referrals  Tenure_in_Months  \
# 0       1   35        0      4                    7                27
# 1       0   45        1     12                   14                13
# 2       1   51        0     21                    4                35
# 3       1   79        0      9                    3                21
# 4       0   80        0     17                    3                 8
#
#    Value_Deal  Phone_Service  Multiple_Lines  Internet_Service  ...  Contract  \
# 0           5              1               0                 1  ...         1
# 1           5              1               1                 1  ...         0
# 2           4              1               0                 1  ...         0
# 3           3              1               0                 1  ...         0
# 4           5              1               0                 1  ...         0
#
#    Paperless_Billing  Payment_Method  Monthly_Charge  Total_Charges  \
# 0                  1               1            65.6         593.30
# 1                  0               1            -4.0         542.40
# 2                  1               0            73.9         280.85
# 3                  1               0            98.0        1237.85
# 4                  1               1            83.9         267.40
#
#    Total_Refunds  Total_Extra_Data_Charges  Total_Long_Distance_Charges  \
# 0           0.00                         0                       381.51
# 1          38.33                        10                        96.21
# 2           0.00                         0                       134.60
# 3           0.00                         0                       361.66
# 4           0.00                         0                        22.14
#
#   Total_Revenue  Customer_Status
# 0        974.81           Stayed
# 1        610.28           Stayed
# 2        415.45          Churned
# 3       1599.51          Churned
# 4        289.54          Churned
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       6418 non-null   int64
#  1   Age                          6418 non-null   int64
#  2   Married                      6418 non-null   int64
#  3   State                        6418 non-null   int64
#  4   Number_of_Referrals          6418 non-null   int64
#  5   Tenure_in_Months             6418 non-null   int64
#  6   Value_Deal                   6418 non-null   int64
#  7   Phone_Service                6418 non-null   int64
#  8   Multiple_Lines               6418 non-null   int64
#  9   Internet_Service             6418 non-null   int64
#  10  Internet_Type                6418 non-null   int64
#  11  Online_Security              6418 non-null   int64
#  12  Online_Backup                6418 non-null   int64
#  13  Device_Protection_Plan       6418 non-null   int64
#  14  Premium_Support              6418 non-null   int64
#  15  Streaming_TV                 6418 non-null   int64
#  16  Streaming_Movies             6418 non-null   int64
#  17  Streaming_Music              6418 non-null   int64
#  18  Unlimited_Data               5028 non-null   object
#  19  Contract                     6418 non-null   int64
#  20  Paperless_Billing            6418 non-null   int64
#  21  Payment_Method               6418 non-null   int64
#  22  Monthly_Charge               6418 non-null   float64
#  23  Total_Charges                6418 non-null   float64
#  24  Total_Refunds                6418 non-null   float64
#  25  Total_Extra_Data_Charges     6418 non-null   int64
#  26  Total_Long_Distance_Charges  6418 non-null   float64
#  27  Total_Revenue                6418 non-null   float64
#  28  Customer_Status              6418 non-null   object
# dtypes: float64(5), int64(22), object(2)
# memory usage: 1.4+ MB

# %%
df['Unlimited_Data'].value_counts()
# Out:
# Unlimited_Data
# Yes    4334
# No      694
# Name: count, dtype: int64

# %%
df['Customer_Status'].value_counts()
# Out:
# Customer_Status
# Stayed     4275
# Churned    1732
# Joined      411
# Name: count, dtype: int64

# %%
df['Customer_Status'].dropna(inplace=True)

# %%
df['Customer_Status'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Customer_Status'] = df['Customer_Status'].map({'Stayed': 0, 'Churned': 1})
df['Unlimited_Data'] = df['Unlimited_Data'].map({'No': 0, 'Yes': 1})
X = df.drop('Customer_Status', axis=1)
y = df['Customer_Status']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6418 entries, 0 to 6417
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       6418 non-null   int64
#  1   Age                          6418 non-null   int64
#  2   Married                      6418 non-null   int64
#  3   State                        6418 non-null   int64
#  4   Number_of_Referrals          6418 non-null   int64
#  5   Tenure_in_Months             6418 non-null   int64
#  6   Value_Deal                   6418 non-null   int64
#  7   Phone_Service                6418 non-null   int64
#  8   Multiple_Lines               6418 non-null   int64
#  9   Internet_Service             6418 non-null   int64
#  10  Internet_Type                6418 non-null   int64
#  11  Online_Security              6418 non-null   int64
#  12  Online_Backup                6418 non-null   int64
#  13  Device_Protection_Plan       6418 non-null   int64
#  14  Premium_Support              6418 non-null   int64
#  15  Streaming_TV                 6418 non-null   int64
#  16  Streaming_Movies             6418 non-null   int64
#  17  Streaming_Music              6418 non-null   int64
#  18  Unlimited_Data               5028 non-null   float64
#  19  Contract                     6418 non-null   int64
#  20  Paperless_Billing            6418 non-null   int64
#  21  Payment_Method               6418 non-null   int64
#  22  Monthly_Charge               6418 non-null   float64
#  23  Total_Charges                6418 non-null   float64
#  24  Total_Refunds                6418 non-null   float64
#  25  Total_Extra_Data_Charges     6418 non-null   int64
#  26  Total_Long_Distance_Charges  6418 non-null   float64
#  27  Total_Revenue                6418 non-null   float64
#  28  Customer_Status              6007 non-null   float64
# dtypes: float64(7), int64(22)
# memory usage: 1.4 MB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 2
#       1 rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
# ----> 2 rf_model.fit(X_train, y_train)
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:360, in BaseForest.fit(self, X, y, sample_weight)
#     357 if issparse(y):
#     358     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 360 X, y = validate_data(
#     361     self,
#     362     X,
#     363     y,
#     364     multi_output=True,
#     365     accept_sparse="csc",
#     366     dtype=DTYPE,
#     367     ensure_all_finite=False,
#     368 )
#     369 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     370 # will raise an error if the underlying tree base estimator can't handle missing
#     371 # values. Only the criterion is required to determine if the tree supports
#     372 # missing values.
#     373 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1387, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    (...)
#    1384     input_name="X",
#    1385 )
# -> 1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#    1391 return X, y
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1397, in _check_y(y, multi_output, y_numeric, estimator)
#    1395 """Isolated part of check_X_y dedicated to y validation"""
#    1396 if multi_output:
# -> 1397     y = check_array(
#    1398         y,
#    1399         accept_sparse="csr",
#    1400         ensure_all_finite=True,
#    1401         ensure_2d=False,
#    1402         dtype=None,
#    1403         input_name="y",
#    1404         estimator=estimator,
#    1405     )
#    1406 else:
#    1407     estimator_name = _check_estimator_name(estimator)
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File c:\Users\RAINA\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.
